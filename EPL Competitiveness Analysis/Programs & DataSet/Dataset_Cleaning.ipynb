# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading and Preprocessing of data

# %%
# Define a list of season names
seasons = ['2002-2003','2003-2004', '2005-2006', '2006-2007', '2007-2008', '2008-2009',
           '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016',
           '2016-2017', '2017-2018', '2018-2019', '2019-2020', '2020-2021', '2021-2022', '2022-2023']


# Create an empty list to store the processed DataFrames
season_dataframes = []

# Loop through each season
for season in seasons:
    # Read the CSV file for the current season
    filename = f'Season {season}.csv'
    data = pd.read_csv(filename)
    print(data.shape)
     
    # Select the required features and copy the DataFrame
    data_selected = data[['Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR',
                         'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']].copy()
    
    # Add the "Season" column with the current season value to the DataFrame using .loc
    data_selected.loc[:, 'Season'] = season
    
    # Reorder the columns to have "Season" as the first column
    data_selected = data_selected[['Season','Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
                                   'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]
    
    # Append the processed DataFrame to the list of season_dataframes
    season_dataframes.append(data_selected)


S_0405=pd.read_csv('Season 2004-2005.csv', encoding="ISO-8859-1",  usecols=range(0, 57))
data1 = S_0405[['Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']].copy()
data1.loc[:, 'Season'] = '2004-2005'
data1 = data1[['Season','Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]
season_dataframes.append(data1)

# Append the "2004-2005" DataFrame to the list of season_dataframes
print(season_dataframes)
# Out:
# (380, 53)
# (380, 57)
# (380, 68)
# (380, 68)
# (380, 71)
# (380, 71)
# (380, 71)
# (380, 71)
# (380, 71)
# (380, 74)
# (380, 68)
# (381, 68)
# (380, 65)
# (380, 65)
# (380, 65)
# (380, 62)
# (380, 106)
# (380, 106)
# (380, 106)
# (380, 106)
# [        Season        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    2002-2003  17/08/2002   Blackburn   Sunderland     0     0   D     0
# 1    2002-2003  17/08/2002    Charlton      Chelsea     2     3   A     2
# 2    2002-2003  17/08/2002     Everton    Tottenham     2     2   D     1
# 3    2002-2003  17/08/2002      Fulham       Bolton     4     1   H     3
# 4    2002-2003  17/08/2002       Leeds     Man City     3     0   H     2
# ..         ...         ...         ...          ...   ...   ...  ..   ...
# 375  2002-2003  11/05/2003       Leeds  Aston Villa     3     1   H     1
# 376  2002-2003  11/05/2003    Man City  Southampton     0     1   A     0
# ...

# %%
# Combine all DataFrames in season_dataframes into a single DataFrame
combined_season_data = pd.concat(season_dataframes, ignore_index=True)

# Now, combined_data contains all the data from all the seasons in one DataFrame
print(combined_season_data)
# Out:
#          Season        Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     2002-2003  17/08/2002    Blackburn     Sunderland   0.0   0.0   D   0.0
# 1     2002-2003  17/08/2002     Charlton        Chelsea   2.0   3.0   A   2.0
# 2     2002-2003  17/08/2002      Everton      Tottenham   2.0   2.0   D   1.0
# 3     2002-2003  17/08/2002       Fulham         Bolton   4.0   1.0   H   3.0
# 4     2002-2003  17/08/2002        Leeds       Man City   3.0   0.0   H   2.0
# ...         ...         ...          ...            ...   ...   ...  ..   ...
# 7976  2004-2005    15/05/05     Man City  Middlesbrough   1.0   1.0   D   0.0
# 7977  2004-2005    15/05/05    Newcastle        Chelsea   1.0   1.0   D   1.0
# 7978  2004-2005    15/05/05  Southampton     Man United   1.0   2.0   A   1.0
# 7979  2004-2005    15/05/05    Tottenham      Blackburn   0.0   0.0   D   0.0
# 7980  2004-2005    15/05/05    West Brom     Portsmouth   2.0   0.0   H   0.0
#
# ...

# %%
# Sort the DataFrame by the 'Date' column in ascending order
combined_season_data = combined_season_data.sort_values(by='Season')

# If you want to sort in descending order, use the following line instead
# combined_data_sorted = combined_data.sort_values(by='Date', ascending=False)

# Print the sorted DataFrame
print(combined_season_data)
# Out:
#          Season        Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     2002-2003  17/08/2002    Blackburn     Sunderland   0.0   0.0   D   0.0
# 1     2002-2003  17/08/2002     Charlton        Chelsea   2.0   3.0   A   2.0
# 2     2002-2003  17/08/2002      Everton      Tottenham   2.0   2.0   D   1.0
# 3     2002-2003  17/08/2002       Fulham         Bolton   4.0   1.0   H   3.0
# 4     2002-2003  17/08/2002        Leeds       Man City   3.0   0.0   H   2.0
# ...         ...         ...          ...            ...   ...   ...  ..   ...
# 7225  2022-2023  06-08-2022    Newcastle  Nott'm Forest   2.0   0.0   H   0.0
# 7224  2022-2023  06-08-2022        Leeds         Wolves   2.0   1.0   H   1.0
# 7223  2022-2023  06-08-2022  Bournemouth    Aston Villa   2.0   0.0   H   1.0
# 7266  2022-2023  31-08-2022  Bournemouth         Wolves   0.0   0.0   D   0.0
# 7222  2022-2023  06-08-2022       Fulham      Liverpool   2.0   2.0   D   1.0
#
# ...

# %%
# Remove rows with NaN values in the 'Date' column
combined_season_data = combined_season_data.dropna(subset=['HomeTeam'])

# Print the DataFrame after removing rows with NaN in 'Date' column
print(combined_season_data)
# Out:
#          Season        Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     2002-2003  17/08/2002    Blackburn     Sunderland   0.0   0.0   D   0.0
# 1     2002-2003  17/08/2002     Charlton        Chelsea   2.0   3.0   A   2.0
# 2     2002-2003  17/08/2002      Everton      Tottenham   2.0   2.0   D   1.0
# 3     2002-2003  17/08/2002       Fulham         Bolton   4.0   1.0   H   3.0
# 4     2002-2003  17/08/2002        Leeds       Man City   3.0   0.0   H   2.0
# ...         ...         ...          ...            ...   ...   ...  ..   ...
# 7225  2022-2023  06-08-2022    Newcastle  Nott'm Forest   2.0   0.0   H   0.0
# 7224  2022-2023  06-08-2022        Leeds         Wolves   2.0   1.0   H   1.0
# 7223  2022-2023  06-08-2022  Bournemouth    Aston Villa   2.0   0.0   H   1.0
# 7266  2022-2023  31-08-2022  Bournemouth         Wolves   0.0   0.0   D   0.0
# 7222  2022-2023  06-08-2022       Fulham      Liverpool   2.0   2.0   D   1.0
#
# ...

# %%
combined_season_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 0 to 7222
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    7980 non-null   object
#  1   Date      7980 non-null   object
#  2   HomeTeam  7980 non-null   object
#  3   AwayTeam  7980 non-null   object
#  4   FTHG      7980 non-null   float64
#  5   FTAG      7980 non-null   float64
#  6   FTR       7980 non-null   object
#  7   HTHG      7980 non-null   float64
#  8   HTAG      7980 non-null   float64
#  9   HTR       7980 non-null   object
#  10  HS        7980 non-null   float64
#  11  AS        7980 non-null   float64
#  12  HST       7980 non-null   float64
#  13  AST       7980 non-null   float64
#  14  HF        7980 non-null   float64
#  15  AF        7980 non-null   float64
#  16  HC        7980 non-null   float64
#  17  AC        7980 non-null   float64
#  18  HY        7980 non-null   float64
# ...

# %%
combined_season_data.shape
# Out:
# (7980, 28)

# %%
pd.isna(combined_season_data).sum()
# Out:
# Season      0
# Date        0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# FTAG        0
# FTR         0
# HTHG        0
# HTAG        0
# HTR         0
# HS          0
# AS          0
# HST         0
# AST         0
# HF          0
# AF          0
# HC          0
# AC          0
# HY          0
# AY          0
# HR          0
# AR          0
# HAGR        0
# AAGR        0
# HAGCR       0
# AAGCR       0
# NAGR        0
# NAGCR       0
# dtype: int64

# %%
# save dataframe into csv file in system
combined_season_data.to_csv('C:/Users/HP/Desktop/DissertationPrograms/Sep_Work/combined_season_data.csv')

# %% [markdown]
# ### Feature Extraction

# %%
# Calculate average home goals and away goals scored for each team
avg_home_goals_scored = combined_season_data.groupby('HomeTeam')['FTHG'].mean()
avg_away_goals_scored = combined_season_data.groupby('AwayTeam')['FTAG'].mean()

# Calculate average home goals and away goals conceded for each team
avg_home_goals_conceded = combined_season_data.groupby('HomeTeam')['FTAG'].mean()
avg_away_goals_conceded = combined_season_data.groupby('AwayTeam')['FTHG'].mean()

# Calculate league's average goals for home and away
league_avg_home_goals = combined_season_data['FTHG'].mean()
league_avg_away_goals = combined_season_data['FTAG'].mean()

# Compute Home and Away Attack Strength and Defence Strength for each match
combined_season_data['HAGR'] = combined_season_data['HomeTeam'].apply(lambda x: avg_home_goals_scored[x] / league_avg_home_goals)
combined_season_data['AAGR'] = combined_season_data['AwayTeam'].apply(lambda x: avg_away_goals_scored[x] / league_avg_away_goals)

combined_season_data['HAGCR'] = combined_season_data['HomeTeam'].apply(lambda x: avg_home_goals_conceded[x] / league_avg_away_goals)
combined_season_data['AAGCR'] = combined_season_data['AwayTeam'].apply(lambda x: avg_away_goals_conceded[x] / league_avg_home_goals)

combined_season_data['NAGR'] = (combined_season_data['HAGR'] + combined_season_data['AAGR']) / 2
combined_season_data['NAGCR'] = (combined_season_data['HAGCR'] + combined_season_data['AAGCR']) / 2

# Extract relevant columns
combined_season_featureextracted = combined_season_data[['Season', 'HomeTeam','HAGR','AAGR' ,'HAGCR','AAGCR','NAGR', 'NAGCR']].drop_duplicates()

combined_season_featureextracted
# Out:
#          Season     HomeTeam      HAGR      AAGR     HAGCR     AAGCR  \
# 0     2002-2003    Blackburn  0.882324  0.750135  0.990630  1.145987
# 1     2002-2003     Charlton  0.861645  1.372106  1.167044  0.664697
# 2     2002-2003      Everton  1.012637  1.217017  0.939149  0.914164
# 3     2002-2003       Fulham  0.896110  0.873021  1.133872  1.109798
# 4     2002-2003        Leeds  0.847858  1.391492  1.384168  0.761530
# ...         ...          ...       ...       ...       ...       ...
# 7225  2022-2023    Newcastle  0.946902  0.497577  1.040388  1.516494
# 7224  2022-2023        Leeds  0.847858  0.799138  1.384168  1.072269
# 7223  2022-2023  Bournemouth  0.896110  0.964997  1.326871  1.060780
# 7266  2022-2023  Bournemouth  0.896110  0.799138  1.326871  1.072269
# 7222  2022-2023       Fulham  0.896110  1.365644  1.133872  0.784507
#
#           NAGR     NAGCR
# 0     0.816229  1.068309
# 1     1.116875  0.915870
# 2     1.114827  0.926656
# 3     0.884566  1.121835
# ...

# %%
combined_season_data.head()
# Out:
#       Season        Date   HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  2002-2003  17/08/2002  Blackburn  Sunderland   0.0   0.0   D   0.0   0.0
# 1  2002-2003  17/08/2002   Charlton     Chelsea   2.0   3.0   A   2.0   1.0
# 2  2002-2003  17/08/2002    Everton   Tottenham   2.0   2.0   D   1.0   0.0
# 3  2002-2003  17/08/2002     Fulham      Bolton   4.0   1.0   H   3.0   1.0
# 4  2002-2003  17/08/2002      Leeds    Man City   3.0   0.0   H   2.0   0.0
#
#   HTR  ...   HY   AY   HR   AR      HAGR      AAGR     HAGCR     AAGCR  \
# 0   D  ...  1.0  2.0  0.0  0.0  0.882324  0.750135  0.990630  1.145987
# 1   H  ...  0.0  3.0  1.0  0.0  0.861645  1.372106  1.167044  0.664697
# 2   H  ...  1.0  1.0  0.0  0.0  1.012637  1.217017  0.939149  0.914164
# 3   H  ...  1.0  2.0  0.0  0.0  0.896110  0.873021  1.133872  1.109798
# 4   H  ...  1.0  1.0  0.0  0.0  0.847858  1.391492  1.384168  0.761530
#
#        NAGR     NAGCR
# 0  0.816229  1.068309
# 1  1.116875  0.915870
# ...

# %%
# save dataframe into csv file in system
combined_season_data.to_csv('C:/Users/HP/Desktop/DissertationPrograms/Final_Work/combined_season_data.csv')
